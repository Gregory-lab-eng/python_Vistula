# %% [markdown]
# <a href="https://colab.research.google.com/github/Gregory-lab-eng/python_Vistula/blob/main/Lab6_Strakhov_75209.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
from transformers import pipeline, AutoModelForCausalLM, AutoTokenizer

# %%
# !nvidia-smi
# Out:
# Sat Jan  3 13:01:06 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   60C    P8             11W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
checkpoint = "distilgpt2"
task = "text-generation"
prompt = "The Gyon neighborhood in Kyoto"

text_generator = pipeline(task = task, model=checkpoint)
output = text_generator(prompt, max_length=200)
print(output[0]["generated_text"])
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cuda:0
# ...

# %%
checkpoint = "distilgpt2"
task = "text-generation"
prompt = "The Gyon neighborhood in Kyoto"

text_generator = pipeline(task = task, model=checkpoint)
output = text_generator(prompt, max_new_tokens=20)
print(output[0]["generated_text"])
# Out:
# Device set to use cuda:0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The Gyon neighborhood in Kyoto, Japan. (Photo credit: Shutterstock.com)

# %%
checkpoint = "distilgpt2"
task = "text-generation"
prompt = "The Gyon neighborhood in Kyoto is famous for"

text_generator = pipeline(task = task, model=checkpoint)
output = text_generator(prompt, max_new_tokens=20)
print(output[0]["generated_text"])
# Out:
# Device set to use cuda:0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The Gyon neighborhood in Kyoto is famous for being the most popular and thriving neighborhood in Tokyo. It was the first and most popular development in the

# %%
output
# Out:
# [{'generated_text': 'The Gyon neighborhood in Kyoto is famous for being the most popular and thriving neighborhood in Tokyo. It was the first and most popular development in the'}]

# %%
import torch

# %%
checkpoint = "distilgpt2"
task = "text-generation"
prompt = "The Gyon neighborhood in Kyoto is famous for"

torch.manual_seed(0)

text_generator = pipeline(task = task, model=checkpoint)
output = text_generator(prompt, max_new_tokens=20)
print(output[0]["generated_text"])
# Out:
# Device set to use cuda:0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The Gyon neighborhood in Kyoto is famous for its colorful and colorful history.

# %%
instruct_checkpoint = "microsoft/Phi-3-mini-4k-instruct"

task = "text-generation"
prompt = "The Gyon neighborhood in Kyoto is famous for"

torch.manual_seed(0)

text_generator = pipeline(task = task, model=instruct_checkpoint)
output_from_intstruct = text_generator(prompt, max_new_tokens=20)
print(output[0]["generated_text"])
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cuda:0
# The Gyon neighborhood in Kyoto is famous for its colorful and colorful history.

# %%
prompt = """Classify the text into neutral, negative or positive.
Text: This movie is definitely on of my favorite.
Sentiment:
"""

text_generator = pipeline(task = task, model=checkpoint)
output = text_generator(prompt, max_new_tokens=20)
print(output[0]["generated_text"])

text_generator = pipeline(task = task, model=instruct_checkpoint)
output_from_intstruct = text_generator(prompt, max_new_tokens=20)
print(output[0]["generated_text"])
# Out:
# Device set to use cuda:0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Classify the text into neutral, negative or positive.
# Text: This movie is definitely on of my favorite.
# Sentiment:
# "What do I think is the best way to describe this movie?"
# "Just think about the
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cuda:0
# Classify the text into neutral, negative or positive.
# Text: This movie is definitely on of my favorite.
# Sentiment:
# "What do I think is the best way to describe this movie?"
# "Just think about the

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="microsoft/Phi-3-mini-4k-instruct")

messages = [
    {"role": "user", "content": "Recommend a book."},
    {"role": "assistant", "content": "generate JSON"},
]

output = pipe(messages, max_new_tokens=20)
print(output[0]["generated_text"])
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.67G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
